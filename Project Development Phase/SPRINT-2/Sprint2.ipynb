# %%
# !pip install squarify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import squarify
from bokeh.plotting import figure, output_file, show
from bokeh.palettes import magma

# %%
data = pd.read_csv("/Global_Superstore2.csv", encoding='unicode_escape')

# %%
plt.plot(data['Sales'])
plt.plot(data['Market'])
 
# Adding Title to the Plot
plt.title("sales by market")
 
# Setting the X and Y labels
plt.xlabel('Sales')
plt.ylabel('Market')
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-41905635d982> in <module>
#       1 plt.plot(data['Sales'])
# ----> 2 plt.plot(data['Market'])
#       3
#       4 # Adding Title to the Plot
#       5 plt.title("sales by market")
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# ...

# %%
sns.lineplot(x="Region", y="Sales", data=data)
 
# setting the title using Matplotlib
plt.title('Sales By Region')
 
plt.show()

# %%
sns.barplot(x='Sales',y='Region', data=data)
 
plt.show()

# %%
gkk = data.groupby(['Sub-Category'])
gkk.first()
# Out:
#               Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# Sub-Category
# Accessories    32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# Appliances     27704    IN-2013-73951    6/6/2013    8/6/2013    Second Class
# Art            14572  ES-2014-2591706  22-09-2014  22-09-2014        Same Day
# Binders        40155   CA-2014-135909  14-10-2014  21-10-2014  Standard Class
# Bookcases      25795    IN-2014-76016  26-09-2014  28-09-2014    Second Class
# Chairs         26341    IN-2013-77878    5/2/2013    7/2/2013    Second Class
# Copiers        47221     SG-2013-4320   5/11/2013   6/11/2013        Same Day
# Envelopes      28658    IN-2013-37929  20-09-2013  22-09-2013    Second Class
# Fasteners      50601      MZ-2014-140  28-06-2014  28-06-2014        Same Day
# Furnishings    38499   CA-2013-120369  29-10-2013  29-10-2013        Same Day
# Labels         38219   CA-2012-134257  16-03-2012  19-03-2012    Second Class
# ...
